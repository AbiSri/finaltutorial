# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import xml.etree.ElementTree as ET
import seaborn as sns
import folium
from folium import plugins
import warnings
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy.polynomial.polynomial as poly
warnings.filterwarnings('ignore')

# %%
calendar = pd.read_csv('calendar.csv')
calendar.head()
# Out:
#    listing_id        date available price
# 0    10988680  2018-04-01         f   NaN
# 1    10988680  2018-03-31         f   NaN
# 2    10988680  2018-03-30         f   NaN
# 3    10988680  2018-03-29         f   NaN
# 4    10988680  2018-03-28         f   NaN

# %%
calendar.size
# Out:
# 12712220

# %%
count = 0

for i in calendar['price']:
    if type(i) == type(0.0) and np.isnan(i):
        count = count + 1
print(count)
# Out:
# 2091162

# %%
listings = pd.read_csv('listings.csv')
listings = listings.rename(columns={"id": "listing_id"})
listings.head()
# Out:
#    listing_id                            listing_url       scrape_id  \
# 0    10988680  https://www.airbnb.com/rooms/10988680  20170401232214
# 1     8053481   https://www.airbnb.com/rooms/8053481  20170401232214
# 2    14011173  https://www.airbnb.com/rooms/14011173  20170401232214
# 3    16142131  https://www.airbnb.com/rooms/16142131  20170401232214
# 4     9080622   https://www.airbnb.com/rooms/9080622  20170401232214
#
#   last_scraped                                           name  \
# 0   2017-04-02               Simple, new, clean accommodation
# 1   2017-04-02            Spacious 2BR/2BATH w/Shared Kitchen
# 2   2017-04-02  Private room - Victorian House in the Mission
# 3   2017-04-02           Spacious 1BR in the Mission District
# 4   2017-04-02             Edwardian flat in heart of Mission
#
#                                              summary  \
# 0  I signed a new lease and moving out of my plac...
# 1  Enjoy the whole main floor of our sunny 2-leve...
# 2  Awesome location in the Mission District of SF...
# 3  Quiet 1 bedroom apartment, with a spacious, we...
# 4  Bedroom with queen bed available.  The condo i...
#
#                                                space  \
# 0  This is clean, simple, affordable accommodatio...
# 1  We love our big, bright home and we know you w...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          description experiences_offered  \
# 0  I signed a new lease and moving out of my plac...                none
# 1  Enjoy the whole main floor of our sunny 2-leve...                none
# 2  Awesome location in the Mission District of SF...                none
# 3  Quiet 1 bedroom apartment, with a spacious, we...                none
# 4  Bedroom with queen bed available.  The condo i...                none
#
#                                neighborhood_overview        ...          \
# 0  Place is very conveniently located in the Miss...        ...
# 1  Our Mission District neighborhood is among the...        ...
# 2                                                NaN        ...
# 3                                                NaN        ...
# 4                                                NaN        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                f     NaN      SAN FRANCISCO
# 1                 9.0                f     NaN      SAN FRANCISCO
# 2                 9.0                f     NaN      SAN FRANCISCO
# 3                 8.0                f     NaN      SAN FRANCISCO
# 4                 NaN                f     NaN      SAN FRANCISCO
#
#   instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                f            flexible                             f
# 1                f              strict                             f
# 2                f            flexible                             f
# 3                f            flexible                             f
# 4                f            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              3
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0               0.07
# 1               0.49
# 2               0.27
# 3               0.48
# 4                NaN
#
# [5 rows x 95 columns]

# %%
reviews = pd.read_csv('reviews.csv', index_col=None)
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     
# 8680  Clean, recently renovated unit in walk-up.  Fu...                none
# 8681  Best location in all of SF. Quiet and just one...                none
# 8682  This remodeled Victorian can't wait to host yo...                none
# 8683  Room w/double bed, desk, window.   We have lis...                none
# 8684  Great space, can accommodate 4 guests. Just un...                none
# 8685  1 bd and private bath in a 2bd/2ba. Beautifull...                none
# 8686  One bedroom in a lovely, well-appointed Missio...                none
# 8687  Stunning apartment boasts the charm of origina...                none
# 8688  My place is in a great location. It is next to...                none
# 8689  Awesome location in the hippest neighborhood i...                none
# 8690  A full floor apartment with one adult bedroom ...                none
# 8691  Relax in an urban oasis! My apartment is a wel...                none
# 8692  Entire Home! This charming bottom floor apartm...                none
# 8693  This cute two bedroom 1 bathroom private apart...                none
# 8694  Spacious 1 bedroom and 1 bathroom in a top-lev...                none
# 8695  Beautiful 1890 Victorian Flat. Share sunny kit...                none
# 8696  Location ! Location ! Location ! Remodeled stu...                none
# 8697  Spacious room in the heart of San Francisco: M...                none
# 8698  Sunny 1-bedroom in the colorful Mission Distri...                none
# 8699  Our beautifully furnished Victorian home in th...                none
# 8700  Clean, professionally cleaned 2BD at the corne...                none
# 8701  Three attractive roommates, hard wood floors, ...                none
# 8702  My place is close to Beretta, Trick Dog, Atlas...                none
# 8703  Beautiful white attic loft. Large window peers...                none
# 8704  The sunlight pours into the tall bay windows i...                none
# 8705  Giant victorian home in the heart of the missi...                none
#
#                                   neighborhood_overview        ...          \
# 0     Place is very conveniently located in the Miss...        ...
# 1     Our Mission District neighborhood is among the...        ...
# 2                                                   NaN        ...
# 3                                                   NaN        ...
# 4                                                   NaN        ...
# 5                                                   NaN        ...
# 6                                                   NaN        ...
# 7     We are located in the middle of the Mission, w...        ...
# 8                                                   NaN        ...
# 9                                                   NaN        ...
# 10    Garfield Square park, right across the street,...        ...
# 11    The Mission District is a vibrant, artsy and d...        ...
# 12    We live in one of the most exciting parts of t...        ...
# 13                                                  NaN        ...
# 14    The Mission is one of SF's most popular neighb...        ...
# 15    Our home is walking distance to everything the...        ...
# 16    We are in the heart of the Mission District, i...        ...
# 17                                                  NaN        ...
# 18    The Mission is an awesome neighborhood, and th...        ...
# 19    We are in great location, surrounded by endles...        ...
# 20                                                  NaN        ...
# 21                                                  NaN        ...
# 22                                                  NaN        ...
# 23                                                  NaN        ...
# 24                                                  NaN        ...
# 25                                                  NaN        ...
# 26    The Mission district has exploded with new caf...        ...
# 27    It's The Mission District. a bit gritty but th...        ...
# 28                                                  NaN        ...
# 29    The apartment is located on 18th street halfwa...        ...
# ...                                                 ...        ...
# 8676                                                NaN        ...
# 8677  There's always a mix of people walking the str...        ...
# 8678  The Mission is easily one of the most the vibr...        ...
# 8679  The location: - The house is in a flat part of...        ...
# 8680  Awesome food, sun (hopefully, but it is El Nin...        ...
# 8681  The Mission Dolores was the first settlement i...        ...
# 8682                                                NaN        ...
# 8683  Lots going on around here.  We have Dolores pa...        ...
# 8684  What can I say about the Mission that you've n...        ...
# 8685                                                NaN        ...
# 8686                                                NaN        ...
# 8687                10.0                f          NaN      SAN FRANCISCO
# 8688                 9.0                f          NaN      SAN FRANCISCO
# 8689                 9.0                f  STR-0000239      SAN FRANCISCO
# 8690                 9.0                f  STR-0000365      SAN FRANCISCO
# 8691                10.0                f          NaN      SAN FRANCISCO
# 8692                10.0                f          NaN      SAN FRANCISCO
# 8693                 9.0                f          NaN      SAN FRANCISCO
# 8694                 9.0                f          NaN      SAN FRANCISCO
# 8695                10.0                f          NaN      SAN FRANCISCO
# 8696                 7.0                f          NaN      SAN FRANCISCO
# 8697                 9.0                f          NaN      SAN FRANCISCO
# 8698                 9.0                f          NaN      SAN FRANCISCO
# 8699                 NaN                f          NaN      SAN FRANCISCO
# 8700                 9.0                f          NaN      SAN FRANCISCO
# 8701                10.0                f          NaN      SAN FRANCISCO
# 8702                10.0                f          NaN      SAN FRANCISCO
# 8703                 9.0                f          NaN      SAN FRANCISCO
# 8704                 9.0                f  STR-0000416      SAN FRANCISCO
# 8705                 NaN                f          NaN      SAN FRANCISCO
#
#      instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                   f            flexible                             f
# 1                   f              strict                             f
# 2                   f            flexible                             f
# 3                   f            flexible                             f
# 4                   f            flexible                             f
# 5                   f            moderate                             f
# 6                   f              strict                             f
# 7                   f              strict                             f
# 8                   f            flexible                             f
# 9                   f            moderate                             f
# 10                  f              strict                             f
# 11                  f              strict                             f
# 12                  f            moderate                             f
# 13                  t            moderate                             f
# 14                  f              strict                             f
# 15                  f              strict                             f
# 16                  t              strict                             f
# 17                  f              strict                             f
# 18                  f              strict                             f
# 19                  f              strict                             f
# 20                  f            moderate                             f
# 21                  f            flexible                             f
# 22                  f            moderate                             f
# 23                  f            flexible                             f
# 24                  f            moderate                             f
# 25                  f              strict                             f
# 26                  f            moderate                             t
# 27                  f              strict                             t
# 28                  f            flexible                             f
# 29                  f            moderate                             f
# ...               ...                 ...                           ...
# 8676                f            flexible                             f
# 8677                f            flexible                             f
# 8678                f            flexible                             f
# 8679                f            moderate                             f
# 8680                f            flexible                             f
# 8681                t            flexible                             f
# 8682                f            flexible                             f
# 8683                t            moderate                             f
# 8684                f            flexible                             f
# 8685                f            flexible                             f
# 8686                t            moderate                             f
# 8687                f              strict                             f
# 8688                f            flexible                             f
# 8689                f              strict                             f
# 8690                f            moderate                             f
# 8691                f            flexible                             f
# 8692                f            moderate                             f
# 8693                f              strict                             f
# 8694                f            moderate                             f
# 8695                f            flexible                             f
# 8696                f            moderate                             f
# 8697                f            flexible                             f
# 8698                f            moderate                             f
# 8699                f              strict                             f
# 8700                f            moderate                             f
# 8701                f            flexible                             f
# 8702                f            flexible                             f
# 8703                t            moderate                             f
# 8704                f            moderate                             f
# 8705                t            flexible                             f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 0                                   f                              1
# 1                                   f                              1
# 2                                   f                              3
# 3                                   f                              1
# 4                                   f                              1
# 5                                   f                              1
# 6                                   f                              1
# 7                                   f                              2
# 8                                   f                              2
# 9                                   f                              3
# 10                                  f                              2
# 11                                  f                              1
# 12                                  f                              1
# 13                                  f                              1
# 14                                  f                              4
# 15                                  f                              1
# 16                                  f                              3
# 17                                  f                              1
# 18                                  f                              2
# 19                                  f                              1
# 20                                  f                              1
# 21                                  f                              1
# 22                                  f                              1
# 23                                  f                              4
# 24                                  f                              1
# 25                                  f                              1
# 26                                  t                              2
# 27                                  t                              2
# 28                                  f                              1
# 29                                  t                              3
# ...                               ...                            ...
# 8676                                f                              1
# 8677                                f                              1
# 8678                                f                              1
# 8679                                f                              6
# 8680                                f                              1
# 8681                                f                              1
# 8682                                f                              1
# 8683                                f                              2
# 8684                                f                              1
# 8685                                f                              1
# 8686                                f                              1
# 8687                                f                              2
# 8688                                f                              1
# 8689                                f                              2
# 8690                                t                              1
# 8691                                f                              3
# 8692                                f                              1
# 8693                                t                              1
# 8694                                f                              1
# 8695                                f                              1
# 8696                                f                              1
# 8697                                f                              1
# 8698                                f                              1
# 8699                                f                              2
# 8700                                f                              1
# 8701                                f                              1
# 8702                                f                              2
# 8703                                f                              4
# 8704                                f                              1
# 8705                                f                              1
#
#       reviews_per_month
# 0                  0.07
# 1                  0.49
# 2                  0.27
# 3                  0.48
# 4                   NaN
# 5                  1.27
# 6                  0.35
# 7                  2.56
# 8                   NaN
# 9                  2.77
# 10                 0.83
# 11                 3.67
# 12                 4.36
# 13                  NaN
# 14                 3.11
# 15                 1.95
# 16                 3.43
# 17                 0.17
# 18                 1.20
# 19                 0.21
# 20                 1.40
# 21                  NaN
# 22                 6.22
# 23                  NaN
# 24                 0.57
# 25                  NaN
# 26                 0.53
# 27                 0.66
# 28                 0.18
# 29                 0.30
# ...                 ...
# 8676                NaN
# 8677               0.68
# 8678                NaN
# 8679               0.59
# 8680                NaN
# 8681               0.14
# 8682               0.49
# 8683               0.36
# 8684               0.28
# 8685               0.66
# 8686               2.02
# 8687               0.30
# 8688               2.86
# 8689               1.52
# 8690               2.95
# 8691               0.15
# 8692               0.65
# 8693               1.65
# 8694               2.32
# 8695               0.86
# 8696               2.81
# 8697               0.32
# 8698               0.98
# 8699                NaN
# 8700               1.76
# 8701               0.18
# 8702               0.24
# 8703               5.30
# 8704               3.67
# 8705                NaN
#
# [8706 rows x 95 columns]

# %%
combined = pd.merge(prices, locations, how='inner', on=['listing_id']).dropna()
combined['price'] = [float(x[1:].replace(',', '')) for x in combined['price']]

# %%
combined
# Out:
#          listing_id  price   latitude   longitude
# 526         8053481  220.0  37.754166 -122.421534
# 527         8053481  220.0  37.754166 -122.421534
# 536         8053481  230.0  37.754166 -122.421534
# 537         8053481  220.0  37.754166 -122.421534
# 538         8053481  220.0  37.754166 -122.421534
# 539         8053481  220.0  37.754166 -122.421534
# 540         8053481  220.0  37.754166 -122.421534
# 541         8053481  220.0  37.754166 -122.421534
# 542         8053481  230.0  37.754166 -122.421534
# 543         8053481  230.0  37.754166 -122.421534
# 544         8053481  220.0  37.754166 -122.421534
# 545         8053481  220.0  37.754166 -122.421534
# 546         8053481  220.0  37.754166 -122.421534
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_zlabel('price')

plt.show()

# %%
lat_x = combined['latitude'][:30000]
lat_y = combined['price'][:30000]

plt.scatter(lat_x, lat_y)
plt.ylim([0, 1500])
plt.show()

# %%
long_x = combined['longitude'][:30000]
long_y = combined['price'][:30000]

plt.scatter(long_x, long_y)
#plt.ylim([0, 1500])
plt.show()

# %%
x_train = combined[['latitude', 'longitude']][1:30000]
y_train = combined['price'][1:30000]

ols = linear_model.LinearRegression()
model = ols.fit(x_train, y_train)

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.intercept_
# Out:
# -1558960.7418219633

# %%
model.coef_
# Out:
# array([ -7204.37864921, -14959.0245567 ])

# %%
x_test = combined[['latitude', 'longitude']][30001:60000]
y_test = combined['price'][30001:60000]

y_pred = model.predict(x_test)
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 41950.0621783
# -0.154426650816

# %%
listings.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
#        'house_rules', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
size_rating = listings[['listing_id', 'square_feet', 'review_scores_rating']].dropna()
print(size_rating.shape)
size_rating.head()
# Out:
# (177, 3)
#      listing_id  square_feet  review_scores_rating
# 35        63405        500.0                  93.0
# 65       815123        170.0                 100.0
# 115       58756        600.0                 100.0
# 124      273452       1100.0                  95.0
# 132      470686        950.0                  98.0

# %%
plt.scatter(size_rating['square_feet'], size_rating['review_scores_rating'])
plt.show()

# %%
price_ratings = listings[['listing_id', 'price', 'review_scores_rating']].dropna()
print(price_ratings.shape)
price_ratings.head()
# Out:
# (6655, 3)
#    listing_id    price  review_scores_rating
# 0    10988680   $49.00                 100.0
# 1     8053481  $220.00                  96.0
# 2    14011173  $100.00                  90.0
# 3    16142131  $117.00                 100.0
# 5      936209  $162.00                  96.0

# %%
price_ratings['price'] = [float(x[1:].replace(',','')) for x in price_ratings['price']]
plt.scatter(price_ratings['price'], price_ratings['review_scores_rating'])
plt.xlim([0, 2000])
plt.show()

# %%
bedroom_price = listings[['listing_id', 'bedrooms', 'price']].dropna()
print(bedroom_price.shape)
bedroom_price.head()
# Out:
# (8698, 3)
#    listing_id  bedrooms    price
# 0    10988680       1.0   $49.00
# 1     8053481       2.0  $220.00
# 2    14011173       1.0  $100.00
# 3    16142131       1.0  $117.00
# 4     9080622       1.0  $200.00

# %%
bedroom_price['price'] = [float(x[1:].replace(',','')) for x in bedroom_price['price']]
plt.scatter(bedroom_price['bedrooms'], bedroom_price['price'])
plt.show()

# %%
bedavg = []
numrooms = []
for x in bedroom_price['bedrooms'].unique():
    bedavg.append(bedroom_price[bedroom_price['bedrooms'] == x]['price'].mean())
    numrooms.append(x)
print(bedavg)
print(numrooms)
plt.scatter(numrooms, bedavg)
plt.show()
# Out:
# [169.53218495013598, 340.9775967413442, 515.85185185185185, 203.6103896103896, 778.10666666666668, 1033.25, 2177.8000000000002, 8500.0, 1804.5, 2050.0]
# [1.0, 2.0, 3.0, 0.0, 4.0, 5.0, 6.0, 10.0, 7.0, 9.0]

# %%
min_x, rng_x = (np.min(numrooms), np.max(numrooms) - np.min(numrooms))
x = 2*(numrooms - min_x) / rng_x - 1.0
X = np.vstack([x**i for i in range(2,-1,-1)]).T
theta = np.linalg.solve(X.T.dot(X), X.T.dot(bedavg))

# %%
theta
# Out:
# array([ 2597.73134717,  2841.51169933,   878.37010669])

# %%
x0 =2*(np.linspace(min_x, min_x+rng_x, 1000) - min_x)/rng_x - 1.0
y0 = [0 for i in range(len(x0))]

for i in range(len(x0)):
    y0[i] = x0[i]**2 * theta[0] + x0[i] * theta[1] + theta[2]

plt.scatter(x0, y0, marker='.')
plt.scatter(x, bedavg)
plt.show()

# %%
error = 0
for i in range(len(x)):
    y_pred = i**2 * theta[0] + i*theta[1] + theta[2]
    error += (y_pred - bedavg[i])**2 / len(x)
print('Mean squared error: ', error)
# Out:
# Mean squared error:  13234261975.8

# %%
coefs = poly.polyfit(x, bedavg, 2)
ffit = poly.polyval(x, coefs)
print(ffit)
plt.scatter(x, ffit)
plt.scatter(x, bedavg)
plt.show()
# Out:
# [  267.70880941   108.64637207   157.4024425    634.58975452   413.97702071
#    878.37010669  1550.58170044  6317.61315319  2430.61180197  4814.12752834]

# %%
error = 0
for i in range(len(x)):
    y_pred = ffit[i]
    error += (y_pred - bedavg[i])**2 / len(x)
print('Mean squared error: ', error)
# Out:
# Mean squared error:  1372305.59459

# %%
def r_squared(n, x, y):
    sum_xy = 0
    for i in range(n):
        sum_xy += x[i]*y[i]
    sum_x = np.sum(x)
    sum_y = np.sum(y)
    sum_x2 = np.sum([i**2 for i in x])
    sum_y2 = np.sum([i**2 for i in y])
    
    r = (n*sum_xy - sum_x*sum_y)
    r /= (n*sum_x2 - sum_x**2)*(n*sum_y2 - sum_y**2)
    
    return r**2

# %%
r_squared(len(x), x, ffit)
# Out:
# 4.63898671540368e-11

# %%
size_price = listings[['listing_id', 'square_feet', 'price']].dropna()
size_price['price'] = [float(x[1:].replace(',','')) for x in size_price['price']]
print(size_price.shape)
size_price.head()
# Out:
# (184, 3)
#      listing_id  square_feet  price
# 35        63405        500.0  125.0
# 65       815123        170.0  130.0
# 75       223213       1100.0  450.0
# 94       486950       1400.0  100.0
# 115       58756        600.0  127.0

# %%
# try and see if there is a relationship between size of place and the price of it.
plt.scatter(size_price['square_feet'], size_price['price'])
plt.show()

# %%
sns.regplot(x='square_feet', y='price', data=size_price)
plt.show()

# %%
x_train = size_price['square_feet']
y_train = size_price['price']

ols = linear_model.LinearRegression()
model = ols.fit(x_train.values.reshape(-1,1), y_train)
print("intercept: ", model.intercept_, "slope: ", model.coef_[0])
y_pred = model.predict(x_train.values.reshape(-1,1))
print("mean squared error: ", mean_squared_error(y_train, y_pred))
print("r^2 value: ", r2_score(y_train, y_pred))
# Out:
# intercept:  165.362043425 slope:  0.0985059258354
# mean squared error:  30101.8244725
# r^2 value:  0.136046441209

# %%
meanprice = []
sizes = []
for x in size_price['square_feet'].unique():
    meanprice.append(size_price[size_price['square_feet'] == x]['price'].mean())
    sizes.append(x)
    
plt.scatter(sizes, meanprice)
plt.show()

# %%
data = listings[['square_feet', 'bedrooms', 'price']].dropna()
data['bedrooms'] = [str(x) for x in data['bedrooms']]
print(data.shape)
print(data['square_feet'].shape)
print(data['bedrooms'].shape)
print(data['price'].shape)
# Out:
# (184, 3)
# (184,)
# (184,)
# (184,)

# %%
#regression = smf.ols(formula='price ~ square_feet*bedrooms', data=data).fit()
#regression.summary()

# %%
listings['access'].unique()
# Out:
# array([ 'You get 24/7 access to your bedroom,bathroom and parking spot. No Access to kitchen/washer/dryer',
#        'We have lived in this home for over 20 years, raised our kids here and recently have done some redecorating. We take pride in keeping our home clean and well maintained. It will be clear of clutter and we will make space in drawers and closets for you.',
#        nan, ...,
#        "Guests will have everything that comes with the apartment: living area, bar, full kitchen with dishwasher (and coffee maker + blender), separate bedroom, and bathroom with tub + shower (and blow dryer). There's laundry right downstairs, as well as a shared back patio with a grill.",
#        'Entire apartment to yourselves!',
#        'You will have access to your room, the bathroom, living room, and kitchen. Again, this is a shared space. We are on the third floor. Stairs only. No elevator :/ great leg workout!'], dtype=object)

# %%
listings.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
#        'house_rules', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
reviews = listings[['host_since', 'reviews_per_month']].dropna()
reviews['host_since'] = [x[:4] for x in reviews['host_since']]
reviews.head()
plt.scatter(reviews['host_since'], reviews['reviews_per_month'])
plt.ylim([0,25])
plt.show()

# %%
revavg = []
year = []
for x in reviews['host_since'].unique():
    revavg.append(reviews[reviews['host_since'] == x]['reviews_per_month'].mean())
    year.append(x)
plt.scatter(year, revavg)
plt.show()

# %%
print('latitude: [', min_lat, max_lat, ']')
print('longitude: [', min_long, max_long, ']')
# Out:
# latitude: [ 37.7069276929 37.8310927851 ]
# longitude: [ -122.51149999 -122.365221992 ]

# %%
lat_range = max_lat - min_lat
long_range = max_long - min_long
print(lat_range, long_range)
# Out:
# 0.124165092156 0.146277997569

# %%
lat_interval = []
long_interval = []
fudge = 0.000005
for i in range(4):
    lat_interval.append([min_lat + i * (lat_range / 4.0) - fudge, min_lat + (i+1)*(lat_range / 4.0) + fudge])
    long_interval.append([min_long + i * (long_range / 4.0) - fudge, min_long + (i+1)*(long_range / 4.0) + fudge])
print(lat_interval)
print(long_interval)
# Out:
# [[37.70692269290489, 37.737973965943922], [37.737963965943919, 37.769015238982959], [37.769005238982956, 37.800056512021996], [37.800046512021993, 37.831097785061026]]
# [[-122.51150498987214, -122.47492549047985], [-122.47493549047985, -122.43835599108756], [-122.43836599108757, -122.40178649169529], [-122.40179649169529, -122.365216992303]]

# %%
combined['group'] = -1
combined.head()
# Out:
#      listing_id  price   latitude   longitude  group
# 526     8053481  220.0  37.754166 -122.421534     -1
# 527     8053481  220.0  37.754166 -122.421534     -1
# 536     8053481  230.0  37.754166 -122.421534     -1
# 537     8053481  220.0  37.754166 -122.421534     -1
# 538     8053481  220.0  37.754166 -122.421534     -1

# %%
combined.shape
# Out:
# (1086893, 5)

# %%
count = [0 for i in range(16)]
for i, row in combined.iterrows():
    for j in range(len(lat_interval)):
        if row['latitude'] >= lat_interval[j][0] and row['latitude'] <= lat_interval[j][1]:
            for k in range(len(long_interval)):
                if row['longitude'] >= long_interval[k][0] and row['longitude'] <= long_interval[k][1]:
                    if count[j*4 + k] < 10000:
#                         combined.loc[[i]]['group'] = j * 4 + k
                        combined.set_value(i,'group', j * 4 + k)
                        count[j*4+k] += 1
# combined[combined['group'] == 1]

# %%
print(count)
# Out:
# [6519, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 221, 10000, 10000, 5116]

# %%
print(combined[combined['group'] == 2]['price'].shape)
print(combined[combined['group'] == 12].shape)
# Out:
# (10000,)
# (221, 5)

# %%
means = []
for i in range(16):
    means.append(combined[combined['group'] == i]['price'].mean())
    print(combined[combined['group'] == i]['price'].mean(), combined[combined['group'] == i]['price'].std())
# Out:
# 202.567264918 151.606907937
# 159.4372 138.970059091
# 211.505 376.700368054
# 115.2171 64.3682413511
# 176.3444 108.799819525
# 221.8664 130.864390496
# 324.0753 721.717322239
# 323.81 357.299849452
# 205.7184 135.439562495
# 234.938 207.855423657
# 303.5551 245.374600221
# 687.6424 1831.12422924
# 110.2760181 3.52662786134
# 385.0161 338.732669849
# 288.7755 181.464785142
# 94.1118060985 63.2008730264

# %%
print(lat_interval[3], long_interval[0])
# Out:
# [37.800046512021993, 37.831097785061026] [-122.51150498987214, -122.47492549047985]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

lat_coord = []
long_coord = []
price_coord = []

for i in range(len(lat_interval)):
    for j in range(len(long_interval)):
        lat_coord.append(lat_interval[i][0])
        long_coord.append(long_interval[j][0])
        price_coord.append(combined[combined['group'] == i*4+j]['price'].mean())

# lat_coord = [x[0] for x in lat_interval]
# long_coord = [x[0] for x in long_interval]
# price_coord = [combined[combined['group'] == x]['price'].mean() for x in range(16)]
print(lat_coord)
print(long_coord)
print(price_coord)

ax.scatter(lat_coord, long_coord, price_coord)
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_zlabel('price')

plt.show()
# Out:
# [37.70692269290489, 37.70692269290489, 37.70692269290489, 37.70692269290489, 37.737963965943919, 37.737963965943919, 37.737963965943919, 37.737963965943919, 37.769005238982956, 37.769005238982956, 37.769005238982956, 37.769005238982956, 37.800046512021993, 37.800046512021993, 37.800046512021993, 37.800046512021993]
# [-122.51150498987214, -122.47493549047985, -122.43836599108757, -122.40179649169529, -122.51150498987214, -122.47493549047985, -122.43836599108757, -122.40179649169529, -122.51150498987214, -122.47493549047985, -122.43836599108757, -122.40179649169529, -122.51150498987214, -122.47493549047985, -122.43836599108757, -122.40179649169529]
# [202.56726491793219, 159.43719999999999, 211.505, 115.2171, 176.34440000000001, 221.8664, 324.07530000000003, 323.81, 205.7184, 234.93799999999999, 303.55509999999998, 687.64239999999995, 110.27601809954751, 385.01609999999999, 288.77550000000002, 94.111806098514464]

# %%
for i in range(16):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    firstgroup = combined[combined['group'] == i]
    lats = firstgroup['latitude']
    longs = firstgroup['longitude']
    prices = firstgroup['price']

    ax.scatter(lats, longs, prices)
    ax.set_xlim([min_lat, max_lat])
    ax.set_ylim([min_long, max_long])
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('price')

    plt.show()

# %%
listings.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
#        'house_rules', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
listings['property_type'].head()
# Out:
# 0    Apartment
# 1    Apartment
# 2        House
# 3    Apartment
# 4    Apartment
# Name: property_type, dtype: object

# %%
map_osm = folium.Map(location=[37.7, -122], zoom_start=11)
#listing_locs = listings[['latitude', 'longitude']].as_matrix()
# map_osm.add_children(plugins.HeatMap(listing_locs, radius=15))

listing_locs = listings[['latitude', 'longitude', 'price']]
listing_locs['price'] = [float(x[1:].replace(',','')) for x in listing_locs['price']]
lats = listing_locs['latitude'].values
longs = listing_locs['longitude'].values
mag = listing_locs['price'].values
map_osm.add_children(plugins.HeatMap(zip(lats, longs, mag), radius=15))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ratings = listings[['neighbourhood', 'review_scores_rating']].dropna()
for x in ratings['neighbourhood'].unique():
    print(ratings[ratings['neighbourhood'] == x]['review_scores_rating'].mean())
# Out:
# 95.3852040816
# 95.4389438944
# 96.175879397
# 96.329153605
# 93.9093655589
# 95.358974359
# 95.8243243243
# 96.6363636364
# 95.7101449275
# 97.375
# 94.8653846154
# 94.6826347305
# 94.472826087
# 95.8454545455
# 94.3333333333
# 95.6133333333
# 91.027027027
# 94.0
# 91.6627906977
# 94.7894736842
# 97.8214285714
# 94.7424242424
# 92.5
# 96.0
# 96.25
# 99.0
# 96.2730496454
# 96.880733945
# 93.2330827068
# 96.1830985915
# 94.9090909091
# 92.5921052632
# 93.4549763033
# 93.4098360656
# 93.8095238095
# 96.5625
# 97.6666666667
# 93.6992481203
# 93.4594594595
# 94.904040404
# 97.25
# 91.8474576271
# 95.35
# 95.6712328767
# 94.6656976744
# 96.2086956522
# 94.6
# 88.7478991597
# 81.0
# 94.5
# 99.6666666667
# 94.3333333333
# 92.6585365854
# 95.0377358491
# 80.8918918919
# 93.3333333333
# 96.6
# 91.619047619
# 90.6
# 92.3947368421

# %%
ratings.head()
# Out:
#       neighbourhood  review_scores_rating
# 0  Mission District                 100.0
# 1  Mission District                  96.0
# 2  Mission District                  90.0
# 3  Mission District                 100.0
# 5  Mission District                  96.0

# %%
nprice = listings[['neighbourhood', 'price']].dropna()
nprice['price'] = [float(x[1:].replace(',','')) for x in nprice['price']]
avg = []
for x in nprice['neighbourhood'].unique():
    avg.append(nprice[nprice['neighbourhood'] == x]['price'].mean())
    print(nprice[nprice['neighbourhood'] == x]['price'].mean())
# Out:
# 219.7
# 272.83197832
# 267.664488017
# 313.181451613
# 202.718274112
# 217.403846154
# 234.604316547
# 224.47311828
# 154.571428571
# 127.454545455
# 243.142857143
# 229.077625571
# 329.55
# 332.654929577
# 309.554347826
# 365.841121495
# 133.284210526
# 197.272727273
# 136.653465347
# 155.130434783
# 554.972222222
# 484.974137931
# 165.058823529
# 339.666666667
# 385.972972973
# 139.0
# 250.69760479
# 212.251908397
# 217.506024096
# 221.638297872
# 310.38
# 211.318584071
# 279.537162162
# 326.212765957
# 314.8875
# 346.623853211
# 454.612244898
# 638.5
# 257.23
# 165.166666667
# 255.6
# 259.915492958
# 237.610738255
# 323.466666667
# 290.154545455
# 281.957446809
# 151.111111111
# 134.736486486
# 170.0
# 199.032258065
# 257.5
# 291.6
# 256.6
# 145.553191489
# 147.793103448
# 138.973451327
# 206.238095238
# 169.694444444
# 136.195652174
# 140.25

# %%
x = []
avgprice = []
y = []

for a in nprice['neighbourhood'].unique():
    x.append(ratings[ratings['neighbourhood'] == a]['review_scores_rating'].mean())
    avgprice.append(x[-1])
    y.append(nprice[nprice['neighbourhood'] == a]['price'].mean())
    
plt.scatter(x, y)
plt.show()

# %%
min_x, rng_x = (np.min(x), np.max(x) - np.min(x))
x = 2*(x - min_x) / rng_x - 1.0

X = np.vstack([x**i for i in range(2,-1,-1)]).T
theta = np.linalg.solve(X.T.dot(X), X.T.dot(y))

# %%
theta
# Out:
# array([  62.62190223,  110.76292839,  185.63958079])

# %%
x0 =2*(np.linspace(min_x, min_x+rng_x, 1000) - min_x)/rng_x - 1.0
y0 = [0 for i in range(len(x0))]

for i in range(len(x0)):
    y0[i] = x0[i]**2 * theta[0] + x0[i] * theta[1] + theta[2]

plt.scatter(x0, y0, marker='.')
plt.scatter(x, y)
plt.show()

# %%
x0 =2*(np.linspace(min_x, np.max(x), 1000) - min_x)/rng_x - 1.0
x0 = np.vstack([x0**i for i in range(2,-1,-1)]).T
y0 = x0.dot(theta)

# %%
x0
# Out:
# array([[  1.        ,  -1.        ,   1.        ],
#        [  1.01711073,  -1.00851908,   1.        ],
#        [  1.0343666 ,  -1.01703815,   1.        ],
#        ...,
#        [ 90.12689295,  -9.49351847,   1.        ],
#        [ 90.28871753,  -9.50203755,   1.        ],
#        [ 90.45068726,  -9.51055662,   1.        ]])

# %%
(lo, hi) = np.min(avgprice), np.max(avgprice)
rng = hi - lo

# %%
listings.columns
# Out:
# Index(['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
#        'house_rules', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
listings['amenities'].unique()
# Out:
# array([ '{Internet,"Wireless Internet","Free parking on premises",Heating,Washer,Dryer,"Smoke detector","Fire extinguisher",Essentials,"24-hour check-in"}',
#        '{TV,"Cable TV","Wireless Internet",Kitchen,Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Hangers,"Hair dryer",Iron,"translation missing: en.hosting_amenity_50"}',
#        '{TV,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke detector","Fire extinguisher",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}',
#        ...,
#        '{Internet,"Wireless Internet",Kitchen,Washer,Dryer,"Fire extinguisher",Essentials,Shampoo,Hangers,"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}',
#        '{Internet,"Wireless Internet",Kitchen,Heating,"Smoke detector","Carbon monoxide detector","First aid kit","Safety card","Fire extinguisher",Essentials,Shampoo,Hangers,"Hair dryer","Laptop friendly workspace","Self Check-In",Lockbox}',
#        '{"Wireless Internet",Kitchen,Breakfast,Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door","Hair dryer","Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50","Private living room"}'], dtype=object)
